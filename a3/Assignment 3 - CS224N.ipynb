# %% [markdown]
# # Question 1
# 1 - Adam optimizer

# %% [markdown]
# a) i) this equation will help smooth out the steps of gradient descent by taking average over more steps rather than just one. So it will prevent overshooting of steps updates.

# %% [markdown]
# a) ii) it helps slow down the updates in the vertical direction which is not needed and speeds up updates in the horizontal direction towards the local minima point. So in a nutshell it somehow slows down the oscillations.

# %% [markdown]
# b) i) 1/prob. TO scale up kept neurons, So we get the a meaningful effect everytime we train. <br>
# ii) because we want in training neurons not to rely on specific inputs, so we train it when these inputs are not available some times, so it spreads out the weight on the input. But in test time we don't the output to be random

# %% [markdown]
# # Question 2 -- Transition based parser

# %% [markdown]
# Stack [Root,parsed]   Buffer [this,sentence,correctly] <br>
# Stack [Root,parsed,this]   Buffer [sentence,correctly] <br>
# Stack [Root,parsed,this,sentence]   Buffer [correctly] <br>
# Left-ARC      <br>
# sentence --> this <br>
# -------------------------------------------------------- <br>
# Stack [Root,parsed,sentence]   Buffer [correctly] <br>
# Right-ARC <br>
# parsed --> sentence <br>
# ------------------------------------------------------- <br>
# Stack [Root,parsed]   Buffer [correctly] <br>
# Stack [Root,parsed,correctly]   Buffer [] <br>
# Right-ARC <br>
# parsed --> correctly <br>
# ------------------------------------------------------- <br>
# Stack [Root,parsed]   Buffer [] <br>
# Left-ARC <br>
# ------------------------------------------------------ <br>
# Stack [Root]   Buffer [] <br>
# Root--> parsed <br>
# ------------------------------------------------------ <br>

# %% [markdown]
# b) 2n + 1

# %%
cd "drive/My Drive/Stanford CS224N/a3"
# Out:
# /content/drive/My Drive/Stanford CS224N/a3

# %%
# !python parser_transitions.py part_c
# Out:
# SHIFT test passed!
# LEFT-ARC test passed!
# RIGHT-ARC test passed!
# parse test passed!

# %%
# !python parser_transitions.py part_d
# Out:
# minibatch_parse test passed!

# %%
# !python parser_transitions.py part_d
# Out:
# minibatch_parse test passed!

# %%
# !python parser_model.py -f
# Out:
# Forward sanity check passes!

# %%
# !python parser_model.py -e
# Out:
# Embedding_lookup sanity check passes!

# %%
# !python run.py
# Out:
# ...
# INITIALIZING
# ...
# Loading data...
# took 1.65 seconds
# Building parser...
# took 1.21 seconds
# Loading pretrained embeddings...
# took 2.20 seconds
# Vectorizing data...
# took 1.52 seconds
# Preprocessing training data...
# took 35.93 seconds
# took 2.79 seconds
#
# ...
# TRAINING
# ...
# Epoch 1 out of 10
# 100% 59136/59136 [06:50<00:00, 144.02it/s]
# Average Train Loss: 0.14465449955517243
# Evaluating on dev set
# 1445850it [00:00, 58812510.92it/s]
# - dev UAS: 86.23
# New best dev UAS! Saving model.
#
# Epoch 2 out of 10
# 100% 59136/59136 [06:50<00:00, 144.03it/s]
# Average Train Loss: 0.10340636368825326
# Evaluating on dev set
# 1445850it [00:00, 45688907.93it/s]
# - dev UAS: 87.48
# New best dev UAS! Saving model.
#
# Epoch 3 out of 10
# 100% 59136/59136 [06:52<00:00, 143.41it/s]
# Average Train Loss: 0.09237745375766639
# Evaluating on dev set
# 1445850it [00:00, 56296677.88it/s]
# - dev UAS: 87.90
# New best dev UAS! Saving model.
#
# Epoch 4 out of 10
# ...

# %% [markdown]
# # Question 2 e)

# %% [markdown]
#  **Error Type :**  Verb Phrase Attachment <br>
#  **Incorrect dependency :** wedding --> fearing  <br>
#  **Correct dependency :** heading --> fearing  <br>

# %% [markdown]
#  **Error Type :**  Coordiantion Attachment Error <br>
#  **Incorrect dependency :** makes --> rescue  <br>
#  **Correct dependency :** people --> rescue  <br>

# %% [markdown]
#  **Error Type :**  Prepositional Phrase Attachment <br>
#  **Incorrect dependency :** named --> Midland  <br>
#  **Correct dependency :** guy --> Midland  <br>

# %% [markdown]
#  **Error Type :**  Modifier Attachment <br>
#  **Incorrect dependency :** elements --> most  <br>
#  **Correct dependency :** crucial --> most  <br>
